# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import bnlearn as bn

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('data/titanic/train.csv').set_index('PassengerId')
test = pd.read_csv('data/titanic/test.csv').set_index('PassengerId')

# %%
train.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Dropping columns with many unique values
drop_list = ['Name', 'Age', 'Cabin', 'Ticket', 'Fare']
train = train.drop(columns=drop_list)
test = test.drop(columns=drop_list)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Embarked  889 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 48.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Sex       418 non-null    object
#  2   SibSp     418 non-null    int64
#  3   Parch     418 non-null    int64
#  4   Embarked  418 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 19.6+ KB

# %%
# Data preparing
dfhot_train, dfnum_train = bn.df2onehot(train)
dfhot_test, dfnum_test = bn.df2onehot(test)
# Out:
# [df2onehot] >Auto detecting dtypes.
# 100%|██████████| 6/6 [00:00<00:00, 230.31it/s]
# [df2onehot] >Set dtypes in dataframe..
# 100%|██████████| 6/6 [00:00<00:00, 342.70it/s]
# [df2onehot] >Total onehot features: 18
#
# [df2onehot] >Auto detecting dtypes.
# 100%|██████████| 5/5 [00:00<00:00, 293.75it/s]
# [df2onehot] >Set dtypes in dataframe..
# 100%|██████████| 5/5 [00:00<00:00, 356.02it/s]
# [df2onehot] >Total onehot features: 14

# %%
dfnum_train
# Out:
#      Survived  Pclass  Sex  SibSp  Parch  Embarked
# 0           0       3    1      2      1         3
# 1           1       1    0      2      1         1
# 2           1       3    0      1      1         3
# 3           1       1    0      2      1         3
# 4           0       3    1      1      1         3
# ..        ...     ...  ...    ...    ...       ...
# 886         0       2    1      1      1         3
# 887         1       1    0      1      1         3
# 888         0       3    0      2      3         3
# 889         1       1    1      1      1         1
# 890         0       3    1      1      1         2
#
# [891 rows x 6 columns]

# %%
dfnum_target = dfnum_train.pop('Survived')

# %%
Xtrain, Xval, Ztrain, Zval = train_test_split(dfnum_train, dfnum_target, test_size=0.2, random_state=0)
valid = pd.concat([Xval, Zval], axis='columns')
dfnum = pd.concat([Xtrain, Ztrain], axis='columns')
dfnum
# Out:
#      Pclass  Sex  SibSp  Parch  Embarked  Survived
# 140       3    0      1      3         1         0
# 439       2    1      1      1         3         0
# 817       2    1      2      2         1         0
# 378       3    1      1      1         1         0
# 491       3    1      1      1         3         0
# ..      ...  ...    ...    ...       ...       ...
# 835       1    0      2      2         1         1
# 192       3    0      2      1         3         1
# 629       3    1      1      1         2         0
# 559       3    0      2      1         3         1
# 684       2    1      2      2         3         0
#
# [712 rows x 6 columns]

# %%
# Get score
def get_acc(model, df, col):
    # Get accuracy score by the model for the validation dataset df with target col
    pred = bn.predict(model, df, variables=[col])
    print(pred)
    acc = accuracy_score(df[col], pred[col])
    print('Accuracy -', acc)
    return acc

# %%
# %%time
# Structure learning
DAG = bn.structure_learning.fit(dfnum, methodtype='hc', root_node='Survived', bw_list_method='nodes', verbose=3)

# Plot
G = bn.plot(DAG)

# Parameter learning
model = bn.parameter_learning.fit(DAG, dfnum, verbose=3);
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >Converting [<class 'pgmpy.base.DAG.DAG'>] to BayesianNetwork model.
# [bnlearn] >Converting adjmat to BayesianNetwork.
# [bnlearn] >CPD of Pclass:
# +-----------+---------------------+---------------------+
# | Survived  | Survived(0)         | Survived(1)         |
# +-----------+---------------------+---------------------+
# | Pclass(1) | 0.2477813276535321  | 0.3501509271237602  |
# +-----------+---------------------+---------------------+
# | Pclass(2) | 0.2594959176428825  | 0.30487278999568784 |
# +-----------+---------------------+---------------------+
# | Pclass(3) | 0.49272275470358534 | 0.344976282880552   |
# +-----------+---------------------+---------------------+
# [bnlearn] >CPD of Embarked:
# +-------------+---------------------+-----+---------------------+
# | Pclass      | Pclass(1)           | ... | Pclass(3)           |
# +-------------+---------------------+-----+---------------------+
# | Embarked(0) | 0.16953642384105963 | ... | 0.11425959780621572 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(1) | 0.28874172185430463 | ... | 0.1855575868372943  |
# +-------------+---------------------+-----+---------------------+
# | Embarked(2) | 0.1675496688741722  | ... | 0.19652650822669104 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(3) | 0.3741721854304636  | ... | 0.5036563071297989  |
# +-------------+---------------------+-----+---------------------+
# [bnlearn] >CPD of Sex:
# +--------+---------------------+-----+--------------------+
# | Parch  | Parch(0)            | ... | Parch(3)           |
# +--------+---------------------+-----+--------------------+
# | Sex(0) | 0.5095057034220533  | ... | 0.5205047318611987 |
# +--------+---------------------+-----+--------------------+
# | Sex(1) | 0.49049429657794674 | ... | 0.4794952681388013 |
# +--------+---------------------+-----+--------------------+
# [bnlearn] >CPD of Survived:
# +-------------+--------------------+---------------------+
# | Sex         | Sex(0)             | Sex(1)              |
# +-------------+--------------------+---------------------+
# | Survived(0) | 0.4190093708165997 | 0.6487046632124353  |
# +-------------+--------------------+---------------------+
# | Survived(1) | 0.5809906291834003 | 0.35129533678756475 |
# +-------------+--------------------+---------------------+
# [bnlearn] >CPD of SibSp:
# +----------+----------+
# | SibSp(0) | 0.103777 |
# +----------+----------+
# | SibSp(1) | 0.381231 |
# +----------+----------+
# | SibSp(2) | 0.194899 |
# +----------+----------+
# | SibSp(3) | 0.111371 |
# +----------+----------+
# | SibSp(4) | 0.103193 |
# +----------+----------+
# | SibSp(5) | 0.10553  |
# +----------+----------+
# [bnlearn] >CPD of Parch:
# +----------+---------------------+-----+---------------------+
# | SibSp    | SibSp(0)            | ... | SibSp(5)            |
# +----------+---------------------+-----+---------------------+
# | Parch(0) | 0.23452157598499063 | ... | 0.23062730627306274 |
# +----------+---------------------+-----+---------------------+
# | Parch(1) | 0.23452157598499063 | ... | 0.23062730627306274 |
# +----------+---------------------+-----+---------------------+
# | Parch(2) | 0.23452157598499063 | ... | 0.26383763837638374 |
# +----------+---------------------+-----+---------------------+
# | Parch(3) | 0.2964352720450281  | ... | 0.27490774907749077 |
# +----------+---------------------+-----+---------------------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# CPU times: total: 188 ms
# Wall time: 463 ms

# %%
# About the model
model
# Out:
# {'model': <pgmpy.models.BayesianNetwork.BayesianNetwork at 0x176e7f38c70>,
#  'adjmat': target    Pclass    Sex  SibSp  Parch  Embarked  Survived
#  source
#  Pclass     False  False  False  False      True     False
#  Sex        False  False  False  False     False      True
#  SibSp      False  False  False   True     False     False
#  Parch      False   True  False  False     False     False
#  Embarked   False  False  False  False     False     False
#  Survived    True  False  False  False     False     False,
#  'config': {'verbose': 3, 'method': 'bayes', 'n_jobs': -1},
#  'model_edges': [('Pclass', 'Embarked'),
#   ('Sex', 'Survived'),
#   ('Survived', 'Pclass'),
#   ('SibSp', 'Parch'),
#   ('Parch', 'Sex')],
#  'structure_scores': {'k2': -3176.1850309006445,
#   'bds': -3186.627937933029,
#   'bic': -3209.323591016363,
#   'bdeu': -3172.7649943218303},
#  'independence_test': None}

# %%
# Get score of the model1
acc1 = get_acc(model, valid, 'Survived')
# Out:
# [bnlearn]> Remaining columns for inference: 5
# 100%|██████████| 59/59 [00:00<00:00, 783.30it/s]
#      Survived         p
# 0           0  0.725084
# 1           0  0.725084
# 2           0  0.725084
# 3           1  0.662098
# 4           0  0.507407
# ..        ...       ...
# 174         0  0.507407
# 175         0  0.725084
# 176         1  0.662098
# 177         0  0.725084
# 178         0  0.725084
#
# [179 rows x 2 columns]
# Accuracy - 0.8156424581005587

# %%
# %%time
# Structure learning
DAG2 = bn.structure_learning.fit(dfnum, methodtype='hc', black_list=['SibSp'], root_node='Survived', bw_list_method='nodes', verbose=4)

# Plot
G2 = bn.plot(DAG2)

# Parameter learning
model2 = bn.parameter_learning.fit(DAG2, dfnum, verbose=4);
# Out:
# [bnlearn] >Filter variables (nodes) on black_list..
# [bnlearn] >Number of features after white/black listing: 5
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# [bnlearn] >Removing columns from dataframe to make consistent with DAG [['SibSp']]
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >Converting [<class 'pgmpy.base.DAG.DAG'>] to BayesianNetwork model.
# [bnlearn] >Converting adjmat to BayesianNetwork.
# [bnlearn] >CPD of Pclass:
# +-----------+----------+
# | Pclass(1) | 0.294003 |
# +-----------+----------+
# | Pclass(2) | 0.279984 |
# +-----------+----------+
# | Pclass(3) | 0.426012 |
# +-----------+----------+
# [bnlearn] >CPD of Embarked:
# +-------------+---------------------+-----+---------------------+
# | Pclass      | Pclass(1)           | ... | Pclass(3)           |
# +-------------+---------------------+-----+---------------------+
# | Embarked(0) | 0.16953642384105963 | ... | 0.11425959780621572 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(1) | 0.28874172185430463 | ... | 0.1855575868372943  |
# +-------------+---------------------+-----+---------------------+
# | Embarked(2) | 0.1675496688741722  | ... | 0.19652650822669104 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(3) | 0.3741721854304636  | ... | 0.5036563071297989  |
# +-------------+---------------------+-----+---------------------+
# [bnlearn] >CPD of Survived:
# +-------------+--------------------+--------------------+--------------------+
# | Pclass      | Pclass(1)          | Pclass(2)          | Pclass(3)          |
# +-------------+--------------------+--------------------+--------------------+
# | Survived(0) | 0.4622516556291391 | 0.5083449235048678 | 0.6343692870201098 |
# +-------------+--------------------+--------------------+--------------------+
# | Survived(1) | 0.5377483443708609 | 0.4916550764951321 | 0.3656307129798903 |
# +-------------+--------------------+--------------------+--------------------+
# [bnlearn] >CPD of Sex:
# +----------+--------------------+--------------------+
# | Survived | Survived(0)        | Survived(1)        |
# +----------+--------------------+--------------------+
# | Sex(0)   | 0.3333333333333333 | 0.5614489003880984 |
# +----------+--------------------+--------------------+
# | Sex(1)   | 0.6666666666666666 | 0.4385510996119017 |
# +----------+--------------------+--------------------+
# [bnlearn] >CPD of Parch:
# +----------+---------------------+---------------------+
# | Sex      | Sex(0)              | Sex(1)              |
# +----------+---------------------+---------------------+
# | Parch(0) | 0.17938420348058903 | 0.13367875647668392 |
# +----------+---------------------+---------------------+
# | Parch(1) | 0.36947791164658633 | 0.5326424870466321  |
# +----------+---------------------+---------------------+
# | Parch(2) | 0.23025435073627845 | 0.17616580310880828 |
# +----------+---------------------+---------------------+
# | Parch(3) | 0.22088353413654618 | 0.15751295336787566 |
# +----------+---------------------+---------------------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# CPU times: total: 203 ms
# Wall time: 359 ms

# %%
# Score of the model2
acc2 = get_acc(model, valid.drop(columns=['SibSp']), 'Survived')
# Out:
# [bnlearn]> Remaining columns for inference: 4
# 100%|██████████| 34/34 [00:00<00:00, 722.31it/s]
#      Survived         p
# 0           0  0.725084
# 1           0  0.725084
# 2           0  0.725084
# 3           1  0.662098
# 4           0  0.507407
# ..        ...       ...
# 174         0  0.507407
# 175         0  0.725084
# 176         1  0.662098
# 177         0  0.725084
# 178         0  0.725084
#
# [179 rows x 2 columns]
# Accuracy - 0.8156424581005587

# %%
# Models comparing
res = bn.bnlearn.compare_networks(model, model2, figsize=(15, 8), verbose=3)
print('Coincidence -', (res[0][0, 0] + res[0][1, 1])/res[0].sum())
# Out:
# Coincidence - 0.76

# %%
# %%time
# Make inference
query = bn.inference.fit(model, variables=['Survived'], evidence={'Sex':True, 'Pclass':True})
print(query)
print(query.df)

# Another inference using only sex for evidence
q1 = bn.inference.fit(model, variables=['Survived'], evidence={'Sex':0})
print(query)
print(query.df)

# Print model
bn.print_CPD(model)
# Out:
# [bnlearn] >Variable Elimination..
# [bnlearn] >Data is stored in [query.df]
# +----+------------+----------+
# |    |   Survived |        p |
# +====+============+==========+
# |  0 |          0 | 0.566487 |
# +----+------------+----------+
# |  1 |          1 | 0.433513 |
# +----+------------+----------+
# +-------------+-----------------+
# | Survived    |   phi(Survived) |
# +=============+=================+
# | Survived(0) |          0.5665 |
# +-------------+-----------------+
# | Survived(1) |          0.4335 |
# +-------------+-----------------+
#    Survived         p
# 0         0  0.566487
# 1         1  0.433513
# [bnlearn] >Variable Elimination..
# [bnlearn] >Data is stored in [query.df]
# +----+------------+----------+
# |    |   Survived |        p |
# +====+============+==========+
# |  0 |          0 | 0.419009 |
# +----+------------+----------+
# |  1 |          1 | 0.580991 |
# +----+------------+----------+
# +-------------+-----------------+
# | Survived    |   phi(Survived) |
# +=============+=================+
# | Survived(0) |          0.5665 |
# +-------------+-----------------+
# | Survived(1) |          0.4335 |
# +-------------+-----------------+
#    Survived         p
# 0         0  0.566487
# 1         1  0.433513
# [bnlearn] >Data is stored in [query.df]
# +----+----------+------------+----------+
# |    |   Pclass |   Survived |        p |
# +====+==========+============+==========+
# |  0 |        1 |          0 | 0.247781 |
# +----+----------+------------+----------+
# |  1 |        1 |          1 | 0.350151 |
# +----+----------+------------+----------+
# |  2 |        2 |          0 | 0.259496 |
# +----+----------+------------+----------+
# |  3 |        2 |          1 | 0.304873 |
# +----+----------+------------+----------+
# |  4 |        3 |          0 | 0.492723 |
# +----+----------+------------+----------+
# |  5 |        3 |          1 | 0.344976 |
# +----+----------+------------+----------+
# CPD of Pclass:
# +-----------+---------------------+---------------------+
# | Survived  | Survived(0)         | Survived(1)         |
# +-----------+---------------------+---------------------+
# | Pclass(1) | 0.2477813276535321  | 0.3501509271237602  |
# +-----------+---------------------+---------------------+
# | Pclass(2) | 0.2594959176428825  | 0.30487278999568784 |
# +-----------+---------------------+---------------------+
# | Pclass(3) | 0.49272275470358534 | 0.344976282880552   |
# +-----------+---------------------+---------------------+
# [bnlearn] >Data is stored in [query.df]
# +----+------------+----------+----------+
# |    |   Embarked |   Pclass |        p |
# +====+============+==========+==========+
# |  0 |          0 |        1 | 0.169536 |
# +----+------------+----------+----------+
# |  1 |          0 |        2 | 0.173853 |
# +----+------------+----------+----------+
# |  2 |          0 |        3 | 0.11426  |
# +----+------------+----------+----------+
# |  3 |          1 |        1 | 0.288742 |
# +----+------------+----------+----------+
# |  4 |          1 |        2 | 0.205146 |
# +----+------------+----------+----------+
# |  5 |          1 |        3 | 0.185558 |
# +----+------------+----------+----------+
# |  6 |          2 |        1 | 0.16755  |
# +----+------------+----------+----------+
# |  7 |          2 |        2 | 0.180111 |
# +----+------------+----------+----------+
# |  8 |          2 |        3 | 0.196527 |
# +----+------------+----------+----------+
# |  9 |          3 |        1 | 0.374172 |
# +----+------------+----------+----------+
# | 10 |          3 |        2 | 0.44089  |
# +----+------------+----------+----------+
# | 11 |          3 |        3 | 0.503656 |
# +----+------------+----------+----------+
# CPD of Embarked:
# +-------------+---------------------+-----+---------------------+
# | Pclass      | Pclass(1)           | ... | Pclass(3)           |
# +-------------+---------------------+-----+---------------------+
# | Embarked(0) | 0.16953642384105963 | ... | 0.11425959780621572 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(1) | 0.28874172185430463 | ... | 0.1855575868372943  |
# +-------------+---------------------+-----+---------------------+
# | Embarked(2) | 0.1675496688741722  | ... | 0.19652650822669104 |
# +-------------+---------------------+-----+---------------------+
# | Embarked(3) | 0.3741721854304636  | ... | 0.5036563071297989  |
# +-------------+---------------------+-----+---------------------+
# [bnlearn] >Data is stored in [query.df]
# +----+-------+---------+----------+
# |    |   Sex |   Parch |        p |
# +====+=======+=========+==========+
# |  0 |     0 |       0 | 0.509506 |
# +----+-------+---------+----------+
# |  1 |     0 |       1 | 0.349367 |
# +----+-------+---------+----------+
# |  2 |     0 |       2 | 0.502924 |
# +----+-------+---------+----------+
# |  3 |     0 |       3 | 0.520505 |
# +----+-------+---------+----------+
# |  4 |     1 |       0 | 0.490494 |
# +----+-------+---------+----------+
# |  5 |     1 |       1 | 0.650633 |
# +----+-------+---------+----------+
# |  6 |     1 |       2 | 0.497076 |
# +----+-------+---------+----------+
# |  7 |     1 |       3 | 0.479495 |
# +----+-------+---------+----------+
# CPD of Sex:
# +--------+---------------------+-----+--------------------+
# | Parch  | Parch(0)            | ... | Parch(3)           |
# +--------+---------------------+-----+--------------------+
# | Sex(0) | 0.5095057034220533  | ... | 0.5205047318611987 |
# +--------+---------------------+-----+--------------------+
# | Sex(1) | 0.49049429657794674 | ... | 0.4794952681388013 |
# +--------+---------------------+-----+--------------------+
# [bnlearn] >Data is stored in [query.df]
# +----+------------+-------+----------+
# |    |   Survived |   Sex |        p |
# +====+============+=======+==========+
# |  0 |          0 |     0 | 0.419009 |
# +----+------------+-------+----------+
# |  1 |          0 |     1 | 0.648705 |
# +----+------------+-------+----------+
# |  2 |          1 |     0 | 0.580991 |
# +----+------------+-------+----------+
# |  3 |          1 |     1 | 0.351295 |
# +----+------------+-------+----------+
# CPD of Survived:
# +-------------+--------------------+---------------------+
# | Sex         | Sex(0)             | Sex(1)              |
# +-------------+--------------------+---------------------+
# | Survived(0) | 0.4190093708165997 | 0.6487046632124353  |
# +-------------+--------------------+---------------------+
# | Survived(1) | 0.5809906291834003 | 0.35129533678756475 |
# +-------------+--------------------+---------------------+
# [bnlearn] >Data is stored in [query.df]
# +----+---------+----------+
# |    |   SibSp |        p |
# +====+=========+==========+
# |  0 |       0 | 0.103777 |
# +----+---------+----------+
# |  1 |       1 | 0.381231 |
# +----+---------+----------+
# |  2 |       2 | 0.194899 |
# +----+---------+----------+
# |  3 |       3 | 0.111371 |
# +----+---------+----------+
# |  4 |       4 | 0.103193 |
# +----+---------+----------+
# |  5 |       5 | 0.10553  |
# +----+---------+----------+
# CPD of SibSp:
# +----------+----------+
# | SibSp(0) | 0.103777 |
# +----------+----------+
# | SibSp(1) | 0.381231 |
# +----------+----------+
# | SibSp(2) | 0.194899 |
# +----------+----------+
# | SibSp(3) | 0.111371 |
# +----------+----------+
# | SibSp(4) | 0.103193 |
# +----------+----------+
# | SibSp(5) | 0.10553  |
# +----------+----------+
# [bnlearn] >Data is stored in [query.df]
# +----+---------+---------+----------+
# |    |   Parch |   SibSp |        p |
# +====+=========+=========+==========+
# |  0 |       0 |       0 | 0.234522 |
# +----+---------+---------+----------+
# |  1 |       0 |       1 | 0.066905 |
# +----+---------+---------+----------+
# |  2 |       0 |       2 | 0.154845 |
# +----+---------+---------+----------+
# |  3 |       0 |       3 | 0.223776 |
# +----+---------+---------+----------+
# |  4 |       0 |       4 | 0.235849 |
# +----+---------+---------+----------+
# |  5 |       0 |       5 | 0.230627 |
# +----+---------+---------+----------+
# |  6 |       1 |       0 | 0.234522 |
# +----+---------+---------+----------+
# |  7 |       1 |       1 | 0.722676 |
# +----+---------+---------+----------+
# |  8 |       1 |       2 | 0.412587 |
# +----+---------+---------+----------+
# |  9 |       1 |       3 | 0.291958 |
# +----+---------+---------+----------+
# | 10 |       1 |       4 | 0.235849 |
# +----+---------+---------+----------+
# | 11 |       1 |       5 | 0.230627 |
# +----+---------+---------+----------+
# | 12 |       2 |       0 | 0.234522 |
# +----+---------+---------+----------+
# | 13 |       2 |       1 | 0.109806 |
# +----+---------+---------+----------+
# | 14 |       2 |       2 | 0.253746 |
# +----+---------+---------+----------+
# | 15 |       2 |       3 | 0.25     |
# +----+---------+---------+----------+
# | 16 |       2 |       4 | 0.275472 |
# +----+---------+---------+----------+
# | 17 |       2 |       5 | 0.263838 |
# +----+---------+---------+----------+
# | 18 |       3 |       0 | 0.296435 |
# +----+---------+---------+----------+
# | 19 |       3 |       1 | 0.100613 |
# +----+---------+---------+----------+
# | 20 |       3 |       2 | 0.178821 |
# +----+---------+---------+----------+
# | 21 |       3 |       3 | 0.234266 |
# +----+---------+---------+----------+
# | 22 |       3 |       4 | 0.25283  |
# +----+---------+---------+----------+
# | 23 |       3 |       5 | 0.274908 |
# +----+---------+---------+----------+
# CPD of Parch:
# +----------+---------------------+-----+---------------------+
# | SibSp    | SibSp(0)            | ... | SibSp(5)            |
# +----------+---------------------+-----+---------------------+
# | Parch(0) | 0.23452157598499063 | ... | 0.23062730627306274 |
# +----------+---------------------+-----+---------------------+
# | Parch(1) | 0.23452157598499063 | ... | 0.23062730627306274 |
# +----------+---------------------+-----+---------------------+
# | Parch(2) | 0.23452157598499063 | ... | 0.26383763837638374 |
# +----------+---------------------+-----+---------------------+
# | Parch(3) | 0.2964352720450281  | ... | 0.27490774907749077 |
# +----------+---------------------+-----+---------------------+
# [bnlearn] >Independencies:
# (SibSp ⟂ Pclass, Survived, Sex, Embarked | Parch)
# (SibSp ⟂ Pclass, Embarked | Survived)
# (SibSp ⟂ Embarked | Pclass)
# (SibSp ⟂ Pclass, Survived, Embarked | Sex)
# (SibSp ⟂ Pclass, Sex, Embarked | Parch, Survived)
# (SibSp ⟂ Survived, Sex, Embarked | Parch, Pclass)
# (SibSp ⟂ Pclass, Survived, Embarked | Parch, Sex)
# (SibSp ⟂ Pclass, Survived, Sex | Parch, Embarked)
# (SibSp ⟂ Embarked | Pclass, Survived)
# (SibSp ⟂ Pclass, Embarked | Survived, Sex)
# (SibSp ⟂ Pclass | Survived, Embarked)
# (SibSp ⟂ Survived, Embarked | Pclass, Sex)
# (SibSp ⟂ Pclass, Survived | Sex, Embarked)
# (SibSp ⟂ Sex, Embarked | Parch, Survived, Pclass)
# (SibSp ⟂ Pclass, Embarked | Parch, Survived, Sex)
# (SibSp ⟂ Pclass, Sex | Parch, Survived, Embarked)
# (SibSp ⟂ Survived, Embarked | Parch, Pclass, Sex)
# (SibSp ⟂ Survived, Sex | Parch, Pclass, Embarked)
# (SibSp ⟂ Pclass, Survived | Parch, Sex, Embarked)
# (SibSp ⟂ Embarked | Pclass, Survived, Sex)
# (SibSp ⟂ Pclass | Survived, Sex, Embarked)
# (SibSp ⟂ Survived | Pclass, Sex, Embarked)
# (SibSp ⟂ Embarked | Parch, Survived, Pclass, Sex)
# (SibSp ⟂ Sex | Parch, Survived, Pclass, Embarked)
# (SibSp ⟂ Pclass | Parch, Survived, Sex, Embarked)
# (SibSp ⟂ Survived | Parch, Pclass, Embarked, Sex)
# (Survived ⟂ SibSp | Parch)
# (Survived ⟂ Embarked | Pclass)
# (Survived ⟂ SibSp, Parch | Sex)
# (Survived ⟂ Embarked | SibSp, Pclass)
# (Survived ⟂ Parch | SibSp, Sex)
# (Survived ⟂ SibSp, Embarked | Parch, Pclass)
# (Survived ⟂ SibSp | Parch, Sex)
# (Survived ⟂ SibSp | Parch, Embarked)
# (Survived ⟂ SibSp, Embarked, Parch | Pclass, Sex)
# (Survived ⟂ SibSp, Parch | Sex, Embarked)
# (Survived ⟂ Embarked | SibSp, Pclass, Parch)
# (Survived ⟂ Parch, Embarked | SibSp, Pclass, Sex)
# (Survived ⟂ Parch | SibSp, Sex, Embarked)
# (Survived ⟂ SibSp, Embarked | Parch, Pclass, Sex)
# (Survived ⟂ SibSp | Parch, Pclass, Embarked)
# (Survived ⟂ SibSp | Parch, Sex, Embarked)
# (Survived ⟂ SibSp, Parch | Pclass, Sex, Embarked)
# (Survived ⟂ Embarked | SibSp, Pclass, Parch, Sex)
# (Survived ⟂ Parch | SibSp, Pclass, Embarked, Sex)
# (Survived ⟂ SibSp | Parch, Pclass, Embarked, Sex)
# (Parch ⟂ Pclass, Embarked | Survived)
# (Parch ⟂ Embarked | Pclass)
# (Parch ⟂ Pclass, Survived, Embarked | Sex)
# (Parch ⟂ Pclass, Embarked | SibSp, Survived)
# (Parch ⟂ Embarked | SibSp, Pclass)
# (Parch ⟂ Pclass, Survived, Embarked | SibSp, Sex)
# (Parch ⟂ Embarked | Pclass, Survived)
# (Parch ⟂ Pclass, Embarked | Survived, Sex)
# (Parch ⟂ Pclass | Survived, Embarked)
# (Parch ⟂ Survived, Embarked | Pclass, Sex)
# (Parch ⟂ Pclass, Survived | Sex, Embarked)
# (Parch ⟂ Embarked | SibSp, Survived, Pclass)
# (Parch ⟂ Pclass, Embarked | SibSp, Survived, Sex)
# (Parch ⟂ Pclass | SibSp, Survived, Embarked)
# (Parch ⟂ Survived, Embarked | SibSp, Pclass, Sex)
# (Parch ⟂ Pclass, Survived | SibSp, Sex, Embarked)
# (Parch ⟂ Embarked | Pclass, Survived, Sex)
# (Parch ⟂ Pclass | Survived, Sex, Embarked)
# (Parch ⟂ Survived | Pclass, Sex, Embarked)
# (Parch ⟂ Embarked | SibSp, Survived, Pclass, Sex)
# (Parch ⟂ Pclass | SibSp, Survived, Sex, Embarked)
# (Parch ⟂ Survived | SibSp, Pclass, Embarked, Sex)
# (Pclass ⟂ SibSp, Sex, Parch | Survived)
# (Pclass ⟂ SibSp | Parch)
# (Pclass ⟂ SibSp, Parch | Sex)
# (Pclass ⟂ Parch, Sex | SibSp, Survived)
# (Pclass ⟂ Parch | SibSp, Sex)
# (Pclass ⟂ SibSp, Sex | Parch, Survived)
# (Pclass ⟂ SibSp, Parch | Survived, Sex)
# (Pclass ⟂ SibSp, Sex, Parch | Survived, Embarked)
# (Pclass ⟂ SibSp | Parch, Sex)
# (Pclass ⟂ SibSp | Parch, Embarked)
# (Pclass ⟂ SibSp, Parch | Sex, Embarked)
# (Pclass ⟂ Sex | SibSp, Survived, Parch)
# (Pclass ⟂ Parch | SibSp, Survived, Sex)
# (Pclass ⟂ Parch, Sex | SibSp, Survived, Embarked)
# (Pclass ⟂ Parch | SibSp, Sex, Embarked)
# (Pclass ⟂ SibSp | Parch, Survived, Sex)
# (Pclass ⟂ SibSp, Sex | Parch, Survived, Embarked)
# (Pclass ⟂ SibSp, Parch | Survived, Sex, Embarked)
# (Pclass ⟂ SibSp | Parch, Sex, Embarked)
# (Pclass ⟂ Sex | SibSp, Survived, Embarked, Parch)
# (Pclass ⟂ Parch | SibSp, Survived, Sex, Embarked)
# (Pclass ⟂ SibSp | Parch, Survived, Sex, Embarked)
# (Sex ⟂ Pclass, Embarked | Survived)
# (Sex ⟂ SibSp | Parch)
# (Sex ⟂ Embarked | Pclass)
# (Sex ⟂ Pclass, Embarked | SibSp, Survived)
# (Sex ⟂ Embarked | SibSp, Pclass)
# (Sex ⟂ SibSp, Pclass, Embarked | Parch, Survived)
# (Sex ⟂ Embarked | Pclass, Survived)
# (Sex ⟂ Pclass | Survived, Embarked)
# (Sex ⟂ SibSp, Embarked | Parch, Pclass)
# (Sex ⟂ SibSp | Parch, Embarked)
# (Sex ⟂ Pclass, Embarked | SibSp, Survived, Parch)
# (Sex ⟂ Embarked | SibSp, Survived, Pclass)
# (Sex ⟂ Pclass | SibSp, Survived, Embarked)
# (Sex ⟂ Embarked | SibSp, Pclass, Parch)
# (Sex ⟂ SibSp, Embarked | Parch, Survived, Pclass)
# (Sex ⟂ SibSp, Pclass | Parch, Survived, Embarked)
# (Sex ⟂ SibSp | Parch, Pclass, Embarked)
# (Sex ⟂ Embarked | SibSp, Survived, Pclass, Parch)
# (Sex ⟂ Pclass | SibSp, Survived, Embarked, Parch)
# (Sex ⟂ SibSp | Parch, Survived, Pclass, Embarked)
# (Embarked ⟂ SibSp, Sex, Parch | Survived)
# (Embarked ⟂ SibSp | Parch)
# (Embarked ⟂ SibSp, Survived, Sex, Parch | Pclass)
# (Embarked ⟂ SibSp, Parch | Sex)
# (Embarked ⟂ Parch, Sex | SibSp, Survived)
# (Embarked ⟂ Parch, Survived, Sex | SibSp, Pclass)
# (Embarked ⟂ Parch | SibSp, Sex)
# (Embarked ⟂ SibSp, Sex | Parch, Survived)
# (Embarked ⟂ SibSp, Sex, Parch | Pclass, Survived)
# (Embarked ⟂ SibSp, Parch | Survived, Sex)
# (Embarked ⟂ SibSp, Survived, Sex | Parch, Pclass)
# (Embarked ⟂ SibSp | Parch, Sex)
# (Embarked ⟂ SibSp, Survived, Parch | Pclass, Sex)
# (Embarked ⟂ Sex | SibSp, Survived, Parch)
# (Embarked ⟂ Parch, Sex | SibSp, Survived, Pclass)
# (Embarked ⟂ Parch | SibSp, Survived, Sex)
# (Embarked ⟂ Survived, Sex | SibSp, Pclass, Parch)
# (Embarked ⟂ Parch, Survived | SibSp, Pclass, Sex)
# (Embarked ⟂ SibSp, Sex | Parch, Survived, Pclass)
# (Embarked ⟂ SibSp | Parch, Survived, Sex)
# (Embarked ⟂ SibSp, Parch | Pclass, Survived, Sex)
# (Embarked ⟂ SibSp, Survived | Parch, Pclass, Sex)
# (Embarked ⟂ Sex | SibSp, Survived, Pclass, Parch)
# (Embarked ⟂ Parch | SibSp, Survived, Pclass, Sex)
# (Embarked ⟂ Survived | SibSp, Pclass, Parch, Sex)
# (Embarked ⟂ SibSp | Parch, Survived, Pclass, Sex)
# [bnlearn] >Nodes: ['Pclass', 'Embarked', 'Sex', 'Survived', 'SibSp', 'Parch']
# [bnlearn] >Edges: [('Pclass', 'Embarked'), ('Sex', 'Survived'), ('Survived', 'Pclass'), ('SibSp', 'Parch'), ('Parch', 'Sex')]
# CPU times: total: 0 ns
# Wall time: 22.5 ms
# {'Pclass':    Pclass  Survived         p
#  0       1         0  0.247781
#  1       1         1  0.350151
#  2       2         0  0.259496
#  3       2         1  0.304873
#  4       3         0  0.492723
#  5       3         1  0.344976,
#  'Embarked':     Embarked  Pclass         p
#  0          0       1  0.169536
#  1          0       2  0.173853
#  2          0       3  0.114260
#  3          1       1  0.288742
#  4          1       2  0.205146
#  5          1       3  0.185558
#  6          2       1  0.167550
#  7          2       2  0.180111
#  8          2       3  0.196527
#  9          3       1  0.374172
#  10         3       2  0.440890
#  11         3       3  0.503656,
#  'Sex':    Sex  Parch         p
#  0    0      0  0.509506
#  1    0      1  0.349367
#  2    0      2  0.502924
#  3    0      3  0.520505
#  4    1      0  0.490494
#  5    1      1  0.650633
#  6    1      2  0.497076
#  7    1      3  0.479495,
#  'Survived':    Survived  Sex         p
#  0         0    0  0.419009
#  1         0    1  0.648705
#  2         1    0  0.580991
#  3         1    1  0.351295,
#  'SibSp':    SibSp         p
#  0      0  0.103777
#  1      1  0.381231
#  2      2  0.194899
#  3      3  0.111371
#  4      4  0.103193
#  5      5  0.105530,
#  'Parch':     Parch  SibSp         p
#  0       0      0  0.234522
#  1       0      1  0.066905
#  2       0      2  0.154845
#  3       0      3  0.223776
#  4       0      4  0.235849
#  5       0      5  0.230627
#  6       1      0  0.234522
#  7       1      1  0.722676
#  8       1      2  0.412587
#  9       1      3  0.291958
#  10      1      4  0.235849
#  11      1      5  0.230627
#  12      2      0  0.234522
#  13      2      1  0.109806
#  14      2      2  0.253746
#  15      2      3  0.250000
#  16      2      4  0.275472
#  17      2      5  0.263838
#  18      3      0  0.296435
#  19      3      1  0.100613
#  20      3      2  0.178821
#  21      3      3  0.234266
#  22      3      4  0.252830
#  23      3      5  0.274908}

# %%
# Prediction using the Bayesian network
Pout = bn.predict(model, df=dfnum_test, variables=['Survived'])
Pout
# Out:
# [bnlearn]> Remaining columns for inference: 5
# 100%|██████████| 84/84 [00:00<00:00, 831.19it/s]
#      Survived         p
# 0           0  0.725084
# 1           0  0.507407
# 2           0  0.611161
# 3           0  0.725084
# 4           0  0.507407
# ..        ...       ...
# 413         0  0.725084
# 414         1  0.662098
# 415         0  0.725084
# 416         0  0.725084
# 417         0  0.725084
#
# [418 rows x 2 columns]

# %%
# Submission
submission = pd.read_csv('data/titanic/gender_submission.csv')
submission['Survived'] = Pout['Survived']
submission.to_csv('data/titanic/submission.csv', index=False)
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
